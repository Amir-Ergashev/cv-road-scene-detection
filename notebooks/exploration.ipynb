# %% [markdown]
# # Exploratory Data Analysis
#
# Исследовательский анализ датасета (подмножество COCO).
# Реализуется на этапе "Выбор и анализ датасета" (день 6-7 плана).
#
# TODO:
# - загрузка аннотаций и подсчёт объектов по классам
# - визуализация примеров изображений с bbox
# - распределение размеров объектов
# - баланс классов

# %%
import sys
sys.path.append('..')
